# %%
from PIL import Image

# %%
picu = Image.open('picu.jpeg')

# %%
type(picu)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
picu
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225 at 0x7FBA05076580>

# %%
# muncul pop up window baru
picu.show()

# %%
picu.size
# Out:
# (225, 225)

# %%
picu.filename
# Out:
# 'picu.jpeg'

# %%
picu.format_description
# Out:
# 'JPEG (ISO 10918)'
